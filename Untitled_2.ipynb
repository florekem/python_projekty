# %%
first = ""
second = ""
count = 0

first = "..."
list(first)
second = "..."
list(second)
for i in range(len(first)):

    if first[i] != second[i]:
        count += 1
print(count)
# Out:
# 527

# %%
string = "..."
subString = "GTGACGCGT"
count = 0
lista = []
print("subString len = "  + str(len(subString)))
for n in range(len(string)):
    cut = string[n:n + len(subString)]
    
    if cut == subString:
        lista.append(n+1)
        
print(lista)
# Out:
# subString len = 9
# [3, 43, 95, 122, 218, 251, 260, 267, 291, 365, 396, 411, 418, 425, 444, 467, 509, 546, 592, 599, 637, 723, 748, 765, 772, 865, 899, 906, 913]

# %%
fasta = 'TCAATGCATGCGGGTCTATATGCAT'

# %%
def cutLen():
    for cutlen in range(4,13):
        for i in range(len(fasta)):
            cut = fasta[i:cutlen+1]
            rev_cut = cut[::-1]
            print(cut)
            print(rev_cut)
            #if cut == rev_cut:
             #   print(cut)
    
cutLen()
# Out:
# TCAAT
# TAACT
# CAAT
# TAAC
# AAT
# TAA
# AT
# TA
# T
# T
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# TCAATG
# GTAACT
# CAATG
# GTAAC
# AATG
# GTAA
# ATG
# GTA
# TG
# GT
# G
# G
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# TCAATGC
# CGTAACT
# CAATGC
# CGTAAC
# AATGC
# CGTAA
# ATGC
# CGTA
# TGC
# CGT
# GC
# CG
# C
# C
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# TCAATGCA
# ACGTAACT
# CAATGCA
# ACGTAAC
# AATGCA
# ACGTAA
# ATGCA
# ACGTA
# TGCA
# ACGT
# GCA
# ACG
# CA
# AC
# A
# A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# TCAATGCAT
# TACGTAACT
# CAATGCAT
# TACGTAAC
# AATGCAT
# TACGTAA
# ATGCAT
# TACGTA
# TGCAT
# TACGT
# GCAT
# TACG
# CAT
# TAC
# AT
# TA
# T
# T
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# TCAATGCATG
# GTACGTAACT
# CAATGCATG
# GTACGTAAC
# AATGCATG
# GTACGTAA
# ATGCATG
# GTACGTA
# TGCATG
# GTACGT
# GCATG
# GTACG
# CATG
# GTAC
# ...
